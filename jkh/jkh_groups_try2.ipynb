# %%
import re
from itertools import islice
from collections import defaultdict
import datetime

import os
import json

import warnings
warnings.filterwarnings("ignore")

import pandas as pd

import numpy as np

import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
ru_stopwords = stopwords.words('russian')

from bertopic import BERTopic

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import ParameterGrid

from sklearn.metrics import recall_score, precision_score, f1_score

from sentence_transformers import SentenceTransformer

import umap

from lib.semconvtree import (
    Geogrid,
    TimePeriodRange,
    GeoTimeAggregator,
    SemConvTree
)

from utils import apply_clean, get_text_and_hashtags

SEED = 42

sentence_model = SentenceTransformer("paraphrase-multilingual-MiniLM-L12-v2")
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Since the GPL-licensed package `unidecode` is not installed, using Python's `unicodedata` package which yields worse results.
# Downloading (…)0fe39/.gitattributes:   0%|          | 0.00/968 [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)83e900fe39/README.md:   0%|          | 0.00/3.79k [00:00<?, ?B/s]
# Downloading (…)e900fe39/config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)tencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Downloading unigram.json:   0%|          | 0.00/14.8M [00:00<?, ?B/s]
# Downloading (…)900fe39/modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %%
# замена функций для вычисления косинусного расстояния, потому что 
# в библиотеке pynndescent, которая используется в bertopic, была проблема
# с библиотекой numpy или где-то ещё

import numba

numba.set_num_threads(8)

@numba.njit(fastmath=True)
def correct_alternative_cosine(ds):
    result = np.empty_like(ds)
    for i in range(ds.shape[0]):
        result[i] = 1.0 - np.power(2.0, ds[i])
    return result

import pynndescent
pynn_dist_fns_fda = pynndescent.distances.fast_distance_alternatives
pynn_dist_fns_fda["cosine"]["correction"] = correct_alternative_cosine
pynn_dist_fns_fda["dot"]["correction"] = correct_alternative_cosine

# %%
vk_posts_df = pd.read_csv('jkh_groups_data/jkh_posts2_processed.csv')
vk_posts_df2 = pd.read_csv('jkh/jkh_posts2_new_processed.csv')
vk_posts_df2.columns = ['Unnamed: 0', 'post_id', 'owner_id', 'date', 'text', 'clean_text', 'similar', 'neg_sent','has_phone', 'from_big_group']

vk_posts_df = pd.concat([vk_posts_df, vk_posts_df2]).drop_duplicates(['post_id', 'owner_id'])

vk_posts_df.drop(columns=['Unnamed: 0'], inplace=True)
not_empty = vk_posts_df[vk_posts_df['clean_text'].str.strip().str.len() > 0]
filtered = not_empty[((not_empty['similar'] == 1) | (not_empty['neg_sent'] == 1)) & (~not_empty['has_phone']) & (~not_empty['from_big_group'])]
print(len(filtered))
filtered.head()
# Out:
# 4049
#                    date  post_id   owner_id  \
# 10  2018-11-23 00:00:00       33 -116263595
# 49  2017-04-15 00:00:00     2269  -26534225
# 52  2017-05-15 00:00:00     2296  -26534225
# 53  2017-05-17 00:00:00     2300  -26534225
# 54  2017-05-20 00:00:00     2307  -26534225
#
#                                                  text  \
# 10  Добрый день. Напротив второй парадной у нас оч...
# 49  Середина апреля 2017 года наступила ...... Где...
# 52  В преддверии годового собрания ТСЖ хотелось бы...
# 53  2.Миф о невозможности заменить трубы - эта зим...
# 54  3. Результаты суда. На самом деле суд указал н...
#
#                                            clean_text  similar  neg_sent  \
# 10  добрый день. напротив второй парадной у нас оч...        1         0
# 49  середина апреля 2017 года наступила ...... где...        0         1
# 52  в преддверии годового собрания тсж хотелось бы...        0         1
# 53  2.миф о невозможности заменить трубы - эта зим...        0         1
# 54  3. результаты суда. на самом деле суд указал н...        0         1
#
#     has_phone  from_big_group
# 10      False           False
# 49      False           False
# 52      False           False
# 53      False           False
# 54      False           False

# %%
vk_groups_df = pd.read_csv('jkh_groups_data/vk_groups_addresses2.csv')
vk_groups_df = vk_groups_df.drop_duplicates(['id'])
vk_groups_df_with_address = vk_groups_df[vk_groups_df.lat.notna()]
vk_groups_df_with_address
# Out:
#              id                                               name  \
# 0     117404680                    ТСЖ "Просвещения 53-1 литер. Д"
# 1     166797525                                ТСЖ "Академическое"
# 4      90003929               ТСЖ "РЖЕВКА" пр. Косыгина 33 корп. 1
# 5     166842485                               ТСЖ Коммуны 48 лит.А
# 7     172336349               ТСЖ Ростовская 5 корпус 2 (Славянка)
# ...         ...                                                ...
# 3143   32581894  Круглый стол «Технологии АНТИЛЕД: дороги, тран...
# 3144   32911093   ЖК Ленинградские вечера, ул. Мебельная д. 47 к.1
# 3145   43601429              5 курс 080507.65(0611)ПЛМиД ИРЭиУ з/о
# 3146   43819015   Народный патруль. Б. Сампсониевский пр. 108, Сер
# 3147   43744485                 Школа собственника по вопросам ЖКХ
#
#                                             description  members_count  \
# 0     Приглашаем в группу неравнодушных жильцов наше...             46
# 1                                                   NaN             15
# 4     группа создана для обслуждения предложений, пр...              3
# 5     Эта группа для всех собственников и проживающи...             15
# 7     Официальная группа собственников жилья дома 5 ...             34
# ...                                                 ...            ...
# 3143  В пятницу, 25 ноября 2011 года, в 12.30 МСК в ...              2
# 3144  Главная площадка собственников и дольщиков дом...            723
# 3145  Институт региональной экономики и управления -...              4
# 3146  Народный Патруль. Б. Самсониевский пр., д.108 ...              5
# 3147  Помощь горожанам в решении самых актуальных во...              6
#
#                                              name_clean  \
# 0                         ТСЖ Просвещения 53-1 литер. Д
# 1                                     ТСЖ Академическое
# 4                    ТСЖ РЖЕВКА пр. Косыгина 33 корп. 1
# 5                                  ТСЖ Коммуны 48 лит.А
# 7                    ТСЖ Ростовская 5 корпус 2 Славянка
# ...                                                 ...
# 3143  Круглый стол Технологии АНТИЛЕД: дороги, транс...
# 3144   ЖК Ленинградские вечера, ул. Мебельная д. 47 к.1
# 3145                5 курс 080507.650611ПЛМиД ИРЭиУ з/о
# 3146   Народный патруль. Б. Сампсониевский пр. 108, Сер
# 3147                 Школа собственника по вопросам ЖКХ
#
#                                       description_clean  \
# 0     Приглашаем в группу неравнодушных жильцов наше...
# 1                                                   NaN
# 4     группа создана для обслуждения предложений, пр...
# 5     Эта группа для всех собственников и проживающи...
# 7     Официальная группа собственников жилья дома 5 ...
# ...                                                 ...
# 3143  В пятницу, 25 ноября 2011 года, в 12.30 МСК в ...
# 3144  Главная площадка собственников и дольщиков дом...
# 3145  Институт региональной экономики и управления -...
# 3146  Народный Патруль. Б. Самсониевский пр., д.108 ...
# 3147  Помощь горожанам в решении самых актуальных во...
#
#                 shortname_tsj_clean                  address_house_clean  \
# 0     ТСЖ Просвещения 53-1, литер д        пр-кт Просвещения, 41 Литер А
# 1                 ТСЖ Академическое                                  NaN
# 4                               NaN  пр-кт Косыгина, 33 корпус 1 Литер А
# 5                               NaN              ул. Коммуны, 48 Литер А
# 7                               NaN   ул. Брюсовская, 5 корпус 2 Литер А
# ...                             ...                                  ...
# 3143                            NaN                                  NaN
# 3144                            NaN                                  NaN
# 3145                            NaN                                  NaN
# 3146                            NaN                                  NaN
# 3147                            NaN                                  NaN
#
#                                             address_tsj  \
# 0     Санкт-Петербург г, пр-кт. Просвещения, д. 53, ...
# 1     Санкт-Петербург г, пр-кт. Гражданский, д. 79, ...
# 4                                                   NaN
# 5                                                   NaN
# 7                                                   NaN
# ...                                                 ...
# 3143                                                NaN
# 3144                                                NaN
# 3145                                                NaN
# 3146                                                NaN
# 3147                                                NaN
#
#                                                name_tsj  ...  \
# 0     Товарищество собственников жилья «Просвещения ...  ...
# 1      Товарищество собственников жилья «Академическое»  ...
# 4                                                   NaN  ...
# 5                                                   NaN  ...
# 7                                                   NaN  ...
# ...                                                 ...  ...
# 3143                                                NaN  ...
# 3144                                                NaN  ...
# 3145                                                NaN  ...
# 3146                                                NaN  ...
# 3147                                                NaN  ...
#
#                                          name_tsj_clean  \
# 0     Товарищество собственников жилья Просвещения 5...
# 1        Товарищество собственников жилья Академическое
# 4                                                   NaN
# 5                                                   NaN
# 7                                                   NaN
# ...                                                 ...
# 3143                                                NaN
# 3144                                                NaN
# 3145                                                NaN
# 3146                                                NaN
# 3147                                                NaN
#
#                             address_house  \
# 0           пр-кт Просвещения, 41 Литер А
# 1                                     NaN
# 4     пр-кт Косыгина, 33 корпус 1 Литер А
# 5                 ул. Коммуны, 48 Литер А
# 7      ул. Брюсовская, 5 корпус 2 Литер А
# ...                                   ...
# 3143                                  NaN
# 3144                                  NaN
# 3145                                  NaN
# 3146                                  NaN
# 3147                                  NaN
#
#                      clusterCaption_house  lat_house  lon_house  \
# 0           пр-кт Просвещения, 41 Литер А  60.047245  30.359553
# 1                                     NaN        NaN        NaN
# 4     пр-кт Косыгина, 33 корпус 1 Литер А  59.944499  30.499430
# 5                 ул. Коммуны, 48 Литер А  59.958444  30.490788
# 7      ул. Брюсовская, 5 корпус 2 Литер А  59.987312  30.423980
# ...                                   ...        ...        ...
# 3143                                  NaN        NaN        NaN
# 3144                                  NaN        NaN        NaN
# 3145                                  NaN        NaN        NaN
# 3146                                  NaN        NaN        NaN
# 3147                                  NaN        NaN        NaN
#
#                clusterCaption_house_clean             city  \
# 0           пр-кт Просвещения, 41 Литер А  санкт-петербург
# 1                                     NaN  санкт-петербург
# 4     пр-кт Косыгина, 33 корпус 1 Литер А  санкт-петербург
# 5                 ул. Коммуны, 48 Литер А  санкт-петербург
# 7      ул. Брюсовская, 5 корпус 2 Литер А  санкт-петербург
# ...                                   ...              ...
# 3143                                  NaN  санкт-петербург
# 3144                                  NaN  санкт-петербург
# 3145                                  NaN  санкт-петербург
# 3146                                  NaN  санкт-петербург
# 3147                                  NaN  санкт-петербург
#
#                                                  street   house  \
# 0                                                   NaN     NaN
# 1                                                   NaN     NaN
# 4                    ТСЖ РЖЕВКА пр. Косыгина 33 корп. 1     NaN
# 5     Эта группа для всех собственников и проживающи...    д.48
# 7     Официальная группа собственников жилья дома 5 ...     NaN
# ...                                                 ...     ...
# 3143                                             дороги  д 2011
# 3144                            ул. Мебельная д. 47 к.1   д. 47
# 3145  Институт региональной экономики и управления -...    д.15
# 3146                             Сампсониевский пр. 108   д.108
# 3147                          00 по адресу улица Марата  дом 14
#
#            coord_source
# 0                   NaN
# 1                   NaN
# 4                   NaN
# 5                   NaN
# 7                   NaN
# ...                 ...
# 3143  city_street_house
# 3144  city_street_house
# 3145  city_street_house
# 3146  city_street_house
# 3147  city_street_house
#
# [2304 rows x 23 columns]

# %%
groups_ids = -vk_groups_df_with_address['id']
filtered.owner_id.isin(groups_ids).sum()
# Out:
# 2835

# %%
filtered[filtered.owner_id.isin(groups_ids)].to_csv('jkh_groups_data/candidates_posts.csv', index=None)

# %%
with open('jkh_groups_data/groups_ids_with_addresses.txt', 'w') as f:
    f.write('\n'.join(map(str, groups_ids.tolist())))

# %% [markdown]
# # Играюсь с размеченными в gpt-3.5 данными
#
# Часть данных была размечена с помощью gpt-3.5, по сути использовалась как дополнительная фильтрация постов на наличие проблемы.
#
# Все посты, которые прошли все шаги фильтрации, используются при тематическом моделировании с помощью bertopic.

# %%
posts_df = pd.read_csv('jkh_groups_data/candidates_posts_labelled.csv', sep='|')
jkh_posts_df = posts_df[posts_df['label'] == 1]

groups_temp_df = vk_groups_df_with_address[['id', 'lat', 'lon']]
groups_temp_df['id'] = -groups_temp_df['id']

jkh_posts_df = jkh_posts_df.merge(groups_temp_df, left_on='owner_id', right_on='id', how='left')

jkh_posts_df
# Out:
#                      date  post_id   owner_id  \
# 0     2018-11-23 00:00:00       33 -116263595
# 1     2017-04-15 00:00:00     2269  -26534225
# 2     2017-05-17 00:00:00     2300  -26534225
# 3     2017-05-20 00:00:00     2307  -26534225
# 4     2017-05-23 00:00:00     2309  -26534225
# ...                   ...      ...        ...
# 1668  2021-09-22 20:18:28      208  -70134067
# 1669  2020-12-10 09:51:26      129  -64635732
# 1670  2021-04-12 12:41:40      173   -8210550
# 1671  2009-03-23 08:05:20        3   -8210550
# 1672  2015-04-15 12:53:06      449  -13674650
#
#                                                    text  \
# 0     Добрый день. Напротив второй парадной у нас оч...
# 1     Середина апреля 2017 года наступила ...... Где...
# 2     2.Миф о невозможности заменить трубы - эта зим...
# 3     3. Результаты суда. На самом деле суд указал н...
# 4     4. Открытая информация и обсуждение всех! вопр...
# ...                                                 ...
# 1668  сумасшедший на уровне 9-10-11этажа 3й - 2й пар...
# 1669  Уважаемые автовладельцы! \nДавайте не будем св...
# 1670  Открытие детского сада на 220 мест на ул. Черк...
# 1671  Да уж.....\nБеседа остановилась на том, что ad...
# 1672  Информация для жителей Невского района!\nБудьт...
#
#                                              clean_text  similar  neg_sent  \
# 0     добрый день. напротив второй парадной у нас оч...        1         0
# 1     середина апреля 2017 года наступила ...... где...        0         1
# 2     2.миф о невозможности заменить трубы - эта зим...        0         1
# 3     3. результаты суда. на самом деле суд указал н...        0         1
# 4     4. открытая информация и обсуждение всех! вопр...        0         1
# ...                                                 ...      ...       ...
# 1668  сумасшедший на уровне 9-10-11этажа 3й - 2й пар...        0         1
# 1669  уважаемые автовладельцы! давайте не будем свин...        0         1
# 1670  открытие детского сада на 220 мест на ул. черк...        0         1
# 1671  да уж..... беседа остановилась на том, что adm...        0         1
# 1672  информация для жителей невского района! будьте...        0         1
#
#       has_phone  from_big_group  label         id        lat        lon
# 0         False           False      1 -116263595  59.938955  30.315644
# 1         False           False      1  -26534225  60.012125  30.333951
# 2         False           False      1  -26534225  60.012125  30.333951
# 3         False           False      1  -26534225  60.012125  30.333951
# 4         False           False      1  -26534225  60.012125  30.333951
# ...         ...             ...    ...        ...        ...        ...
# 1668      False           False      1  -70134067  59.937540  30.350687
# 1669      False           False      1  -64635732  59.938955  30.315644
# 1670      False           False      1   -8210550  60.030721  30.426199
# 1671      False           False      1   -8210550  60.030721  30.426199
# 1672      False           False      1  -13674650  59.938955  30.315644
#
# [1673 rows x 13 columns]

# %%
jkh_docs = jkh_posts_df.clean_text.tolist()
jkh_embeddings = sentence_model.encode(jkh_docs, show_progress_bar=False)

# %%
vectorizer_model = CountVectorizer(stop_words=ru_stopwords, ngram_range=(1, 2))
topic_model_jkh_posts = BERTopic(language="multilingual", vectorizer_model=vectorizer_model, min_topic_size=6, calculate_probabilities=True)

# %%
topics, probs = topic_model_jkh_posts.fit_transform(jkh_docs, jkh_embeddings)

# %%
topic_model_jkh_posts.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1    504                             -1_это_дома_тсж_соседи
# 1       0    279                           0_воды_горячей_вода_воду
# 2       1    138            1_отопление_квитанции_батареи_отопления
# 3       2     77                        2_ремонт_парадной_это_стены
# 4       3     48                    3_света_свет_освещение_работает
# 5       4     41                        4_лифт_лифты_работают_лифте
# 6       5     39                         5_дворе_площадки_грязь_это
# 7       6     30                      6_дверь_двери_парадной_дверей
# 8       7     29                       7_собак_собака_собаки_собаку
# 9       8     29                          8_ночи_спать_время_слышно
# 10      9     28                     9_кв_тсж_задолженность_жильцов
# 11     10     27          10_голосования_голосов_бюллетени_собрание
# 12     11     27                 11_парковки_машины_территории_мест
# 13     12     25                      12_мусор_мусора_отходов_вывоз
# 14     13     24                          13_дома_тсж_нашего_деньги
# 15     14     23                      14_снега_снег_чистят_тротуары
# 16     15     23                15_крысы_тараканов_тараканы_крысами
# 17     16     22                  16_тсж_собрания_решения_правления
# 18     17     19                       17_курит_окурок_курить_пожар
# 19     18     18                  18_камеры_молодых_этаже_подростки
# 20     19     15                           19_портал_санкт_кнут_экз
# 21     20     15                     20_вашем доме_вашем_доме_какие
# 22     21     14  21_парадной_парадная_уважаемые соседи_соседи п...
# 23     22     13                  22_парадной_парадную_мозгов_вечер
# 24     23     13                    23_свиньи_живут_пакеты_парадной
# 25     24     12              24_авто_автомобиль_машину_парковаться
# 26     25     12  25_собрание_голосовали_собственники_собственности
# 27     26     12         26_мошенники_нами_квартиру_видеонаблюдения
# 28     27     11                     27_машину_совесть_08_уважаемые
# 29     28     11      28_дворов_второго двора_дорогие соседи_недель
# 30     29     10                   29_просто_мкд_управляющей_работы
# 31     30      9                      30_урны_дровяной_скамеек_ноги
# 32     31      9       31_соседи_активные действия_активные_чердака
# 33     32      9                      32_иг_группе_бюллетень_группу
# 34     33      8              33_мусоропровод_парадная_пакета_засор
# 35     34      8               34_копию ключа_ключа_антей_тсж антей
# 36     35      8             35_пива_страница_имейте совесть_имейте
# 37     36      7                  36_макарова_жа макарова_жа_каляев
# 38     37      7                 37_мусор_гидранты_соседи_уважаемые
# 39     38      7  38_капремонте_наш знаем_дом дейсвительно_ситуа...
# 40     39      7                  39_лифтов_капремонт_иг_этому шагу
# 41     40      6  40_окончания_мусороприемники_окончания работ_р...
#
#                                        Representation  \
# 0   [это, дома, тсж, соседи, нашего, нам, сегодня,...
# 1   [воды, горячей, вода, воду, холодной, горячей ...
# 2   [отопление, квитанции, батареи, отопления, руб...
# 3   [ремонт, парадной, это, стены, ремонта, работы...
# 4   [света, свет, освещение, работает, домофон, эт...
# 5   [лифт, лифты, работают, лифте, лифтов, вообще,...
# 6   [дворе, площадки, грязь, это, детской, качели,...
# 7   [дверь, двери, парадной, дверей, доводчик, руч...
# 8   [собак, собака, собаки, собаку, это, площадке,...
# 9   [ночи, спать, время, слышно, утра, совесть, сп...
# 10  [кв, тсж, задолженность, жильцов, деньги, плат...
# 11  [голосования, голосов, бюллетени, собрание, пр...
# 12  [парковки, машины, территории, мест, парковку,...
# 13  [мусор, мусора, отходов, вывоз, сбора, жильцов...
# 14  [дома, тсж, нашего, деньги, зато, которые, наш...
# 15  [снега, снег, чистят, тротуары, дорогу, снегом...
# 16  [крысы, тараканов, тараканы, крысами, решать, ...
# 17  [тсж, собрания, решения, правления, собственни...
# 18  [курит, окурок, курить, пожар, подоконнике, ку...
# 19  [камеры, молодых, этаже, подростки, девушка, д...
# 20  [портал, санкт, кнут, экз, пряник, верблюд, им...
# 21  [вашем доме, вашем, доме, какие, хочу, жильцы,...
# 22  [парадной, парадная, уважаемые соседи, соседи ...
# 23  [парадной, парадную, мозгов, вечер, этажа, спя...
# 24  [свиньи, живут, пакеты, парадной, обшего польз...
# 25  [авто, автомобиль, машину, парковаться, другим...
# 26  [собрание, голосовали, собственники, собственн...
# 27  [мошенники, нами, квартиру, видеонаблюдения, б...
# 28  [машину, совесть, 08, уважаемые, подъезд, свин...
# 29  [дворов, второго двора, дорогие соседи, недель...
# 30  [просто, мкд, управляющей, работы, администрац...
# 31  [урны, дровяной, скамеек, ноги, понимаю, наше ...
# 32  [соседи, активные действия, активные, чердака,...
# 33  [иг, группе, бюллетень, группу, мнение, группа...
# 34  [мусоропровод, парадная, пакета, засор, этажом...
# 35  [копию ключа, ключа, антей, тсж антей, приема,...
# 36  [пива, страница, имейте совесть, имейте, совес...
# 37  [макарова, жа макарова, жа, каляев, правления,...
# 38  [мусор, гидранты, соседи, уважаемые, уважаемые...
# 39  [капремонте, наш знаем, дом дейсвительно, ситу...
# 40  [лифтов, капремонт, иг, этому шагу, капремонт ...
# 41  [окончания, мусороприемники, окончания работ, ...
#
#                                   Representative_Docs
# 0   [дорогие друзья, жители дома! эта группа созда...
# 1   [кто нибудь знает, почему горячей воды нет?, г...
# 2   [добрый день! елена, подскажите пожалуйста, в ...
# 3   [у нас в прошлом году в 7-й парадной выше 5 эт...
# 4   [пожар в грщ-4 был! я звонила сегодня в аварий...
# 5   [снова лифты работают с проблемами.средний про...
# 6   [дорогие соседи! уборка дворов или её отсутств...
# 7   [какими должны быть входные двери подъездов в ...
# 8   [уважаемые соседи, жильцы арсенальной,3 срочна...
#   'уважаемые собственники квартир, члены товарищества ! наш дом не продан ук, как вам преподносит иг. пока будет идти проверка фактов , подтверждающих законность выборов нового правления, дом должен обслуживаться должным образом. от того, что давыдов посадил двух охранников в диспетчерской, которые находятся там круглосуточно, дом к отопительному сезону не подготовиться. не поддавайтесь на провокации иг! все не так как они говорят! как пишет иг на счету тсж 170 000 рублей, но почему они не пишут, что по состоянию на 01.07.2013 я рассчиталась со всеми поставщиками коммунальных услуг, тсж не должник! а охрану в диспетчерской они со своего кармана оплатят, или их спонсоры, которые стоят за их спиной?'],
#  40: ['луначарского 7 к.2 парадная 5. на последнем этаже 9-этажного дома у мусоропровода не убирается. валяются коробки, бумага, строит.материалы уже давно... я понимаю, что виновато бескультурье соседей, но почему убирают только 1и 2 этажи  вычитала в "графике уборки...". всегда считалось, что самые загрязненные - это 1ый и последний этажи, но не 2ой. как обратить на это внимание жилищные службы?',
#   'кто подскажет! по чьему велению ворота в помойке перестали закрывать от слова вообще! проходишь мимо и взглядом натыкаешься на мусор. еще и запах! живем как в деревне с воротами на распашку. кто-то раньше ведь эти ворота закрывал! при карпове должность упразднили что ли? или функцию? вроде зарплата у персонала меньше не стала. и техник в тсж есть еще на нашу голову. народу стало больше, толку стало меньше.',
#   'внимание! 20.07.2015 с 11-00 и до окончания работ: чистка вентиляционных каналов! с 24-го июля закрываются камеры мусоропровода на всех этажах! причина: санитарная обработка! срок: 14 дней! просьба отнестись с пониманием и выносить свой мусор в мусороприемники во дворе! мусоропровод будет отпечатан до окончания работ! дополнительно будет вывешено объявление!']}

# %%
topic_model_jkh_posts.save("jkh_groups_data/jkh_bertopic_posts2.pickle")

# %%
jkh_posts_df['topic'] = topics
jkh_posts_df.to_csv('jkh_groups_data/posts_with_topic.csv', index=None)

# %%
with open('jkh_groups_data/project-7-at-2023-05-01-12-54-a4f45cc1.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

temp = {k: [x[k] for x in data] for k in data[0].keys()}
jkh_prob_df = pd.DataFrame(temp)
jkh_prob_df['manual_label'] = [int(x.startswith('Есть')) for x in jkh_prob_df['sentiment']]
jkh_posts_df = jkh_posts_df.merge(jkh_prob_df[['post_id', 'owner_id', 'manual_label']], on=['post_id', 'owner_id'], how='left')
jkh_posts_df
# Out:
#                      date  post_id   owner_id  \
# 0     2018-11-23 00:00:00       33 -116263595
# 1     2017-04-15 00:00:00     2269  -26534225
# 2     2017-05-17 00:00:00     2300  -26534225
# 3     2017-05-20 00:00:00     2307  -26534225
# 4     2017-05-23 00:00:00     2309  -26534225
# ...                   ...      ...        ...
# 1678  2021-09-22 20:18:28      208  -70134067
# 1679  2020-12-10 09:51:26      129  -64635732
# 1680  2021-04-12 12:41:40      173   -8210550
# 1681  2009-03-23 08:05:20        3   -8210550
# 1682  2015-04-15 12:53:06      449  -13674650
#
#                                                    text  \
# 0     Добрый день. Напротив второй парадной у нас оч...
# 1     Середина апреля 2017 года наступила ...... Где...
# 2     2.Миф о невозможности заменить трубы - эта зим...
# 3     3. Результаты суда. На самом деле суд указал н...
# 4     4. Открытая информация и обсуждение всех! вопр...
# ...                                                 ...
# 1678  сумасшедший на уровне 9-10-11этажа 3й - 2й пар...
# 1679  Уважаемые автовладельцы! \nДавайте не будем св...
# 1680  Открытие детского сада на 220 мест на ул. Черк...
# 1681  Да уж.....\nБеседа остановилась на том, что ad...
# 1682  Информация для жителей Невского района!\nБудьт...
#
#                                              clean_text  similar  neg_sent  \
# 0     добрый день. напротив второй парадной у нас оч...        1         0
# 1     середина апреля 2017 года наступила ...... где...        0         1
# 2     2.миф о невозможности заменить трубы - эта зим...        0         1
# 3     3. результаты суда. на самом деле суд указал н...        0         1
# 4     4. открытая информация и обсуждение всех! вопр...        0         1
# ...                                                 ...      ...       ...
# 1678  сумасшедший на уровне 9-10-11этажа 3й - 2й пар...        0         1
# 1679  уважаемые автовладельцы! давайте не будем свин...        0         1
# 1680  открытие детского сада на 220 мест на ул. черк...        0         1
# 1681  да уж..... беседа остановилась на том, что adm...        0         1
# 1682  информация для жителей невского района! будьте...        0         1
#
#       has_phone  from_big_group  label         id        lat        lon  \
# 0         False           False      1 -116263595  59.938955  30.315644
# 1         False           False      1  -26534225  60.012125  30.333951
# 2         False           False      1  -26534225  60.012125  30.333951
# 3         False           False      1  -26534225  60.012125  30.333951
# 4         False           False      1  -26534225  60.012125  30.333951
# ...         ...             ...    ...        ...        ...        ...
# 1678      False           False      1  -70134067  59.937540  30.350687
# 1679      False           False      1  -64635732  59.938955  30.315644
# 1680      False           False      1   -8210550  60.030721  30.426199
# 1681      False           False      1   -8210550  60.030721  30.426199
# 1682      False           False      1  -13674650  59.938955  30.315644
#
#       topic  manual_label
# 0         2           0.0
# 1        -1           0.0
# 2         0           0.0
# 3         1           0.0
# 4         4           0.0
# ...     ...           ...
# 1678      5           NaN
# 1679     -1           NaN
# 1680     -1           NaN
# 1681     -1           NaN
# 1682     16           NaN
#
# [1683 rows x 15 columns]

# %%
jkh_posts_df.to_csv('jkh_groups_data/jkh_posts2_final.csv', sep='|', index=None)

# %%
jkh_posts_df = pd.read_csv('jkh_groups_data/jkh_posts2_final.csv', sep='|')

# %%
topic_model_jkh_comments = BERTopic.load("jkh_groups_data/jkh_bertopic_posts2.pickle")

# %% [markdown]
# # SemConvTree
#
# Использую SemConvTree из неопубликованной на текущий момент статьи SemConvTree

# %%
jkh_docs = jkh_posts_df.clean_text.tolist()
jkh_embeddings = sentence_model.encode(jkh_docs, show_progress_bar=False)

topics, probs = topic_model_jkh_posts.transform(jkh_docs, jkh_embeddings)

# %%
probs_ = probs / np.linalg.norm(probs, ord=1, axis=-1)[..., np.newaxis]
probs_.sum()
# Out:
# 1683.0

# %%
is_labelled = jkh_posts_df['manual_label'].notna().values
labels = jkh_posts_df[is_labelled]['manual_label'].values

# %%
# поиск с помощью GridSearch
# оцениваю насколько хорошо модель SemConvTree выделяет сообщения с проблемой лифта,
# то есть SemConvTree присваивает некоторый вес каждому сообщению, зачем этот вес по
# по порогу k переводится в 1 или 0, после чего вычисляется метрика F1.

TOPICS_TO_SEARCH = np.array([5])

df = jkh_posts_df
docs = jkh_docs

best_ver = None

results_dir = 'results_jkh'
os.makedirs(results_dir, exist_ok=True)

params_grid = {
    'n_range': [5, 10, 25, 50, 75, 100],
    'alpha': [0.1, 0.2, 0.5, 0.7, 1.0],
    'beta_topic': [1.0, 2.0, 3.0, 5.0, 10.0],
    'tpr_mode': ['year_month', 'year_3month'], #, 'busday'],
    'k': [1.5, 3.0, 5.0, 7.0]
#     'active_zone_threshold': [2.0, 5.0, 10.0],
#     'post_weight_threshold': [1.1, 1.5, 2.0],
}

def one_run(df, docs, probs, n_range, alpha, beta_topic, tpr_mode, path, k=5.0):
    geogrid = Geogrid(
        df['lat'].min(),
        df['lat'].max(),
        df['lon'].min(),
        df['lon'].max(),
        n_range=n_range,
    )

    tpr = TimePeriodRange(mode=tpr_mode)
    sct = SemConvTree(alpha, beta)
    
    sem_agg_topics = sct.transform(
        df[['lat', 'lon', 'date']].values,
        probs_, geogrid, tpr,
        return_active_zone_posts=False
    )
    
    all_posts_weights = sct.weighted_topics
    
    max_weight_posts_idxs = np.argpartition(all_posts_weights, -10)[-10:]
    min_weight_posts_idxs = np.argpartition(all_posts_weights, 10)[:10]
    
    norm_sem_agg_topics = sct.get_norm_sem_agg_topics()
    sem_agg_topics = sct.get_sem_agg_topics()
    lat_idxs, lon_idxs, time_idxs = sct.get_posts_idxs()
    
    active_zones_idxs = np.argsort(sem_agg_topics, axis=None)
    active_zones_idxs = active_zones_idxs[-50:]
    threshold = np.sort(sem_agg_topics.flat[active_zones_idxs])[-10]
    active_zones_idxs = active_zones_idxs[sem_agg_topics.flat[active_zones_idxs] > threshold]
    
    os.makedirs(path, exist_ok=True)
    with open(f'{path}/config.json', 'w', encoding='utf-8') as f:
        json.dump(params, f)
        
    with open(f'{path}/max_weights_posts.txt', 'w', encoding='utf-8') as f:
        f.write('\n'.join(map(lambda x: f'{x} | {np.round(all_posts_weights[x], 3)} | {docs[x]}', max_weight_posts_idxs)))
        
    with open(f'{path}/min_weights_posts.txt', 'w', encoding='utf-8') as f:
        f.write('\n'.join(map(lambda x: f'{x} | {np.round(all_posts_weights[x], 3)} | {docs[x]}', min_weight_posts_idxs)))
    
    
    with open(f'{path}/active_zones.txt', 'w', encoding='utf-8') as f:
        f.write('\n'.join(map(lambda x: f'{x} {sem_agg_topics.flat[x]}', active_zones_idxs)))
        
    os.makedirs(f'{path}/active_zone_posts', exist_ok=True)
    for idx in active_zones_idxs:
        in_active_zone_fn = lambda x: x[1][0]*tpr.n_range*n_range+x[1][1]*tpr.n_range+x[1][2] == idx
        posts_idxs_in_zone = filter(in_active_zone_fn, enumerate(zip(lat_idxs, lon_idxs, time_idxs)))
        with open(f'{path}/active_zone_posts/{idx}', 'w', encoding='utf-8') as f:
            f.write('\n'.join(map(lambda x: f'{x[0]} | {np.round(all_posts_weights[x[0]], 3)} | {docs[x[0]]}', posts_idxs_in_zone)))
    
    algo_res_for_metrics = (all_posts_weights[is_labelled] > k).astype(int)
    
    metrics = {}
    metrics['avg_posts_count_in_cell'] = len(df) / len(set(zip(lat_idxs, lon_idxs, time_idxs)))
    metrics['recall'] = recall_score(labels, algo_res_for_metrics)
    metrics['precision'] = precision_score(labels, algo_res_for_metrics)
    metrics['f1'] = f1_score(labels, algo_res_for_metrics)
    
    with open(f'{path}/metrics.json', 'w') as f:
        json.dump(metrics, f)

for ver, params in enumerate(ParameterGrid(params_grid)):
    # GeoGrid params
    n_range = params['n_range']
    # SemConvTree params
    alpha = params['alpha']
    beta = np.zeros(probs_.shape[1])
    for topic in TOPICS_TO_SEARCH:
        beta[topic] = params['beta_topic']
    tpr_mode = params['tpr_mode']
    k = params['k']
#     active_zone_threshold = params['active_zone_threshold']
#     post_weight_threshold = params['post_weight_threshold']
    
    path = f'{results_dir}/v{ver:03d}'
    one_run(df, docs, probs_, n_range, alpha, beta, tpr_mode, path, k=k)

# %%
metrics_data = defaultdict(list)

for ver in os.listdir('results_jkh'):
    metrics_data['ver'].append(ver)
    with open(f'results_jkh/{ver}/metrics.json', 'r') as f:
        d = json.load(f)
    for k in d:
        metrics_data[k].append(d[k])
    with open(f'results_jkh/{ver}/config.json', 'r') as f:
        d = json.load(f)
    for k in d:
        metrics_data[k].append(d[k])

metrics_df = pd.DataFrame(metrics_data)
metrics_df = metrics_df.sort_values(['f1'], ascending=False)

# %%
metrics_df
# Out:
#         ver  avg_posts_count_in_cell  recall  precision        f1  alpha  \
# 1155   v112                 2.047445     0.2   0.269231  0.229508    0.1
# 642    v064                 2.047445     0.2   0.269231  0.229508    0.1
# 536    v435                 8.904762     0.4   0.159091  0.227642    0.2
# 759    v387                 8.904762     0.4   0.159091  0.227642    0.2
# 693    v291                 8.904762     0.4   0.157303  0.225806    0.2
# ...     ...                      ...     ...        ...       ...    ...
# 457    v613                13.795082     0.0   0.000000  0.000000    0.5
# 458   v1096                 2.047445     0.0   0.000000  0.000000    1.0
# 461    v795                 8.904762     0.0   0.000000  0.000000    0.7
# 462    v660                 4.822350     0.0   0.000000  0.000000    0.5
# 1199   v332                 1.839344     0.0   0.000000  0.000000    0.2
#
#       beta_topic    k  n_range     tpr_mode
# 1155         3.0  3.0       25   year_month
# 642          2.0  3.0       25   year_month
# 536         10.0  1.5       10  year_3month
# 759          5.0  1.5       10  year_3month
# 693          2.0  1.5       10  year_3month
# ...          ...  ...      ...          ...
# 457          3.0  7.0        5  year_3month
# 458          3.0  7.0       25   year_month
# 461          2.0  5.0       10  year_3month
# 462          5.0  7.0        5   year_month
# 1199         2.0  7.0       75   year_month
#
# [1200 rows x 10 columns]

# %%
k = 7.0
metrics_df[metrics_df['k'] == k]
# Out:
#         ver  avg_posts_count_in_cell    recall  precision        f1  alpha  \
# 786    v088                 2.047445  0.085714       1.00  0.157895    0.1
# 616    v184                 2.047445  0.085714       1.00  0.157895    0.1
# 388    v232                 2.047445  0.085714       1.00  0.157895    0.1
# 559    v136                 2.047445  0.085714       1.00  0.157895    0.1
# 495    v040                 2.047445  0.085714       0.75  0.153846    0.1
# ...     ...                      ...       ...        ...       ...    ...
# 453    v189                 3.105166  0.000000       0.00  0.000000    0.1
# 457    v613                13.795082  0.000000       0.00  0.000000    0.5
# 458   v1096                 2.047445  0.000000       0.00  0.000000    1.0
# 462    v660                 4.822350  0.000000       0.00  0.000000    0.5
# 1199   v332                 1.839344  0.000000       0.00  0.000000    0.2
#
#       beta_topic    k  n_range     tpr_mode
# 786          2.0  7.0       25   year_month
# 616          5.0  7.0       25   year_month
# 388         10.0  7.0       25   year_month
# 559          3.0  7.0       25   year_month
# 495          1.0  7.0       25   year_month
# ...          ...  ...      ...          ...
# 453          5.0  7.0       75  year_3month
# 457          3.0  7.0        5  year_3month
# 458          3.0  7.0       25   year_month
# 462          5.0  7.0        5   year_month
# 1199         2.0  7.0       75   year_month
#
# [300 rows x 10 columns]

# %% [markdown]
# ## Веса сообщений для каждого топика
#
# то есть выставляется внимание каждый раз только на один топик

# %%
def one_run_2(df, probs, n_range, alpha, beta, tpr_mode):
    geogrid = Geogrid(
        df['lat'].min(),
        df['lat'].max(),
        df['lon'].min(),
        df['lon'].max(),
        n_range=n_range,
    )

    tpr = TimePeriodRange(mode=tpr_mode)
    sct = SemConvTree(alpha, beta)
    
    _ = sct.transform(
        df[['lat', 'lon', 'date']].values,
        probs, geogrid, tpr,
        return_active_zone_posts=False
    )
    
    all_posts_weights = sct.weighted_topics
    
    return all_posts_weights

# %%
best_ver = metrics_df.head(1)['ver'].values[0]
with open(f'results_jkh/{best_ver}/config.json', 'r') as f:
    best_params = json.load(f)

for topic in range(1, probs_.shape[1]):
    n_range = best_params['n_range']
    # SemConvTree params
    alpha = best_params['alpha']
    beta = np.zeros(probs_.shape[1])
    beta[topic] = best_params['beta_topic']
    tpr_mode = best_params['tpr_mode']
    
    posts_weights = one_run_2(df, probs_, n_range, alpha, beta, tpr_mode)
    np.save(f'jkh_groups_data/specific_topic/{topic}.npy', posts_weights)

# %% [markdown]
# ## Вычисляю веса уже для сообщений до фильтрации с помощью GPT

# %%
posts2_df = pd.read_csv('jkh_groups_data/candidates_posts_labelled.csv', sep='|')
posts2_df
# Out:
#                      date  post_id   owner_id  \
# 0     2018-11-23 00:00:00       33 -116263595
# 1     2017-04-15 00:00:00     2269  -26534225
# 2     2017-05-15 00:00:00     2296  -26534225
# 3     2017-05-17 00:00:00     2300  -26534225
# 4     2017-05-20 00:00:00     2307  -26534225
# ...                   ...      ...        ...
# 2830  2009-03-22 12:14:52        2   -8210550
# 2831  2020-03-18 07:03:27      623  -13674650
# 2832  2015-05-08 22:31:23      456  -13674650
# 2833  2015-04-15 12:53:06      449  -13674650
# 2834  2015-01-21 18:06:52      438  -13674650
#
#                                                    text  \
# 0     Добрый день. Напротив второй парадной у нас оч...
# 1     Середина апреля 2017 года наступила ...... Где...
# 2     В преддверии годового собрания ТСЖ хотелось бы...
# 3     2.Миф о невозможности заменить трубы - эта зим...
# 4     3. Результаты суда. На самом деле суд указал н...
# ...                                                 ...
# 2830  Сайт УЧИТЕЛЬ закрыт для неугодных...)   Скопир...
# 2831  Максимальный репост. Президент группы компаний...
# 2832  Дорогие ветераны Великой Отечественной войны и...
# 2833  Информация для жителей Невского района!\nБудьт...
# 2834  ГОЛОСУЕМ ЗА ОТСТАВКУ НЕРАДИВОГО ЧИНОВНИКА!\n\n...
#
#                                              clean_text  similar  neg_sent  \
# 0     добрый день. напротив второй парадной у нас оч...        1         0
# 1     середина апреля 2017 года наступила ...... где...        0         1
# 2     в преддверии годового собрания тсж хотелось бы...        0         1
# 3     2.миф о невозможности заменить трубы - эта зим...        0         1
# 4     3. результаты суда. на самом деле суд указал н...        0         1
# ...                                                 ...      ...       ...
# 2830  сайт учитель закрыт для неугодных... скопирова...        0         1
# 2831  максимальный репост. президент группы компаний...        0         1
# 2832  дорогие ветераны великой отечественной войны и...        0         1
# 2833  информация для жителей невского района! будьте...        0         1
# 2834  голосуем за отставку нерадивого чиновника! ува...        0         1
#
#       has_phone  from_big_group  label
# 0         False           False      1
# 1         False           False      1
# 2         False           False      0
# 3         False           False      1
# 4         False           False      1
# ...         ...             ...    ...
# 2830      False           False      0
# 2831      False           False      0
# 2832      False           False      0
# 2833      False           False      1
# 2834      False           False      0
#
# [2835 rows x 10 columns]

# %%
topic_model_jkh_posts = BERTopic.load("jkh_groups_data/jkh_bertopic_posts")

# %%
posts_df = pd.read_csv('jkh_groups_data/candidates_posts3.csv', sep='|')
posts2_df = pd.read_csv('jkh_groups_data/candidates_posts_labelled.csv', sep='|')
posts2_df = posts2_df[posts2_df.columns[:-1]]

groups_temp_df = pd.read_csv('jkh_groups_data/vk_groups_addresses2.csv', usecols=['id', 'lat', 'lon']).drop_duplicates('id')
groups_temp_df['id'] = -groups_temp_df['id']

posts2_df = posts2_df.merge(groups_temp_df, left_on='owner_id', right_on='id', how='left').drop(columns='id')

posts_df = pd.concat([posts2_df, posts_df])

posts_docs = posts_df.clean_text.tolist()
posts_embeddings = sentence_model.encode(posts_docs, show_progress_bar=False)

_, posts_probs = topic_model_jkh_posts.transform(posts_docs, posts_embeddings)

posts_probs_ = posts_probs / np.linalg.norm(posts_probs, ord=1, axis=-1)[..., np.newaxis]

# %%
posts_df.to_csv('jkh_groups_data/candidates_posts_with_3.csv', sep='|', index=None)

# %%
best_ver = metrics_df.head(1)['ver'].values[0]
with open(f'results_jkh/{best_ver}/config.json', 'r') as f:
    best_params = json.load(f)

for topic in range(probs_.shape[1]):
    n_range = best_params['n_range']
    # SemConvTree params
    alpha = best_params['alpha']
    beta = np.zeros(probs_.shape[1])
    beta[topic] = best_params['beta_topic']
    tpr_mode = best_params['tpr_mode']
    
    posts_weights = one_run_2(posts_df, posts_probs_, n_range, alpha, beta, tpr_mode)
    np.save(f'jkh_groups_data/specific_topic2/{topic}.npy', posts_weights)

# %%
# здесь внимание выставляется сразу нескольким топикам, потенциально их надо вручную выбрать
# так, чтобы среди них были только топики с ЖКХ проблемами

TOPICS_TO_SEARCH = [0, 4, 6, 13, 12, 15, 16, 23, 24]

n_range = best_params['n_range']
# SemConvTree params
alpha = best_params['alpha']
beta = np.zeros(posts_probs_.shape[1])
for topic in TOPICS_TO_SEARCH:
    beta[topic] = best_params['beta_topic']
tpr_mode = best_params['tpr_mode']

posts_weights = one_run_2(posts_df, posts_probs_, n_range, alpha, beta, tpr_mode)
np.save(f'jkh_groups_data/specific_topic2/all_posts_with_3.npy', posts_weights)

# %%
vk_posts3_df = pd.read_csv('jkh/jkh_posts3_processed.csv')

not_empty = vk_posts3_df[vk_posts3_df['clean_text'].str.strip().str.len() > 0]
filtered = not_empty[((not_empty['similar'] == 1) | (not_empty['neg_sent'] == 1)) & (~not_empty['has_phone']) & (~not_empty['from_big_group'])]
print(len(filtered))

filtered.to_csv('jkh_groups_data/candidates_posts3.csv', sep='|', index=None)
# Out:
# 2349

# %% [markdown]
# # Проверка
#
# проверяю отдельные закупки на то, какие сообщения были до закупки и после

# %%
timestamps = ['2021-02-10', '2022-01-27', '2019-09-19', '2020-11-20', '2020-11-30', '2021-06-16', '2021-03-15', '2022-11-07', '2022-07-19']
lats = [59.943214, 59.943214, 59.926575, 59.940001, 59.92267, 60.006152, 60.009107, 59.833072, 59.918756]
lons = [30.479442, 30.479442, 30.377933, 30.469956, 30.448792, 30.252429, 30.24898, 30.312329, 30.469184]

timestamps = [datetime.datetime.strptime(ts,'%Y-%m-%d') for ts in timestamps]

# %%
posts_df = pd.read_csv('jkh_groups_data/candidates_posts_with_3.csv', sep='|')

# %%
best_ver = metrics_df.head(1)['ver'].values[0]
with open(f'results_jkh/{best_ver}/config.json', 'r') as f:
    best_params = json.load(f)

n_range = best_params['n_range']
tpr_mode = best_params['tpr_mode']

df = posts_df

geogrid = Geogrid(
    df['lat'].min(),
    df['lat'].max(),
    df['lon'].min(),
    df['lon'].max(),
    n_range=n_range,
)

tpr = TimePeriodRange(mode=tpr_mode)

test_geo_idxs = geogrid.get_grid_idxs(lats, lons)
test_tpr_idxs = tpr.get_range_idxs(timestamps)

posts_geo_idxs = geogrid.get_grid_idxs(df['lat'], df['lon'])
posts_tpr_idxs = tpr.get_range_idxs(df['date'])

# %%
before_offset = 1
after_offset = 1
min_change = 0.2

for cntr in range(len(timestamps)):
    geo_cond = (posts_geo_idxs[0] == test_geo_idxs[0][cntr]) & (posts_geo_idxs[1] == test_geo_idxs[1][cntr])
        
    before_cond = (test_tpr_idxs[cntr] - before_offset <= posts_tpr_idxs) & (test_tpr_idxs[cntr] >= posts_tpr_idxs)
    after_cond = (test_tpr_idxs[cntr] <= posts_tpr_idxs) & (test_tpr_idxs[cntr] + after_offset >= posts_tpr_idxs)

    print(f'{timestamps[cntr]=} | {lats[cntr]=} | {lons[cntr]=}')
    for topic in range(0, posts_probs_.shape[1]):
        posts_weights = np.load(f'jkh_groups_data/specific_topic2/{topic}.npy')
        
        before_mean = posts_weights[geo_cond & before_cond].mean()
        after_mean = posts_weights[geo_cond & after_cond].mean()
        if abs(before_mean - after_mean) > min_change:
            print(f"{topic=} | {(geo_cond & before_cond).sum()=} | {(geo_cond & after_cond).sum()=} | {before_mean=:0.3f} | {after_mean=:0.3f}")
    
    posts_weights = np.load(f'jkh_groups_data/specific_topic2/all_posts_with_3.npy')
        
    before_mean = posts_weights[geo_cond & before_cond].mean()
    after_mean = posts_weights[geo_cond & after_cond].mean()
    if before_mean > after_mean + 0.2:
        print(f"all_posts_with_3 | {(geo_cond & before_cond).sum()=} | {(geo_cond & after_cond).sum()=} | {before_mean=:0.3f} | {after_mean=:0.3f}")
    
    print('-'*100)
# Out:
# timestamps[cntr]=datetime.datetime(2021, 2, 10, 0, 0) | lats[cntr]=59.943214 | lons[cntr]=30.479442
# topic=36 | (geo_cond & before_cond).sum()=22 | (geo_cond & after_cond).sum()=25 | before_mean=1.125 | after_mean=0.822
# ----------------------------------------------------------------------------------------------------
# timestamps[cntr]=datetime.datetime(2022, 1, 27, 0, 0) | lats[cntr]=59.943214 | lons[cntr]=30.479442
# topic=4 | (geo_cond & before_cond).sum()=24 | (geo_cond & after_cond).sum()=28 | before_mean=0.870 | after_mean=0.645
# topic=6 | (geo_cond & before_cond).sum()=24 | (geo_cond & after_cond).sum()=28 | before_mean=0.874 | after_mean=0.640
# topic=10 | (geo_cond & before_cond).sum()=24 | (geo_cond & after_cond).sum()=28 | before_mean=1.149 | after_mean=0.920
# topic=12 | (geo_cond & before_cond).sum()=24 | (geo_cond & after_cond).sum()=28 | before_mean=0.941 | after_mean=0.706
# topic=14 | (geo_cond & before_cond).sum()=24 | (geo_cond & after_cond).sum()=28 | before_mean=0.939 | after_mean=0.710
# topic=15 | (geo_cond & before_cond).sum()=24 | (geo_cond & after_cond).sum()=28 | before_mean=0.856 | after_mean=0.597
# topic=16 | (geo_cond & before_cond).sum()=24 | (geo_cond & after_cond).sum()=28 | before_mean=1.033 | after_mean=0.820
# topic=18 | (geo_cond & before_cond).sum()=24 | (geo_cond & after_cond).sum()=28 | before_mean=0.880 | after_mean=0.640
# topic=23 | (geo_cond & before_cond).sum()=24 | (geo_cond & after_cond).sum()=28 | before_mean=0.945 | after_mean=0.691
# topic=25 | (geo_cond & before_cond).sum()=24 | (geo_cond & after_cond).sum()=28 | before_mean=0.894 | after_mean=0.666
# topic=28 | (geo_cond & before_cond).sum()=24 | (geo_cond & after_cond).sum()=28 | before_mean=0.972 | after_mean=0.703
# topic=30 | (geo_cond & before_cond).sum()=24 | (geo_cond & after_cond).sum()=28 | before_mean=0.933 | after_mean=0.694
# topic=31 | (geo_cond & before_cond).sum()=24 | (geo_cond & after_cond).sum()=28 | before_mean=1.215 | after_mean=0.976
# topic=34 | (geo_cond & before_cond).sum()=24 | (geo_cond & after_cond).sum()=28 | before_mean=0.946 | after_mean=0.745
# topic=37 | (geo_cond & before_cond).sum()=24 | (geo_cond & after_cond).sum()=28 | before_mean=1.097 | after_mean=0.707
# ----------------------------------------------------------------------------------------------------
# timestamps[cntr]=datetime.datetime(2019, 9, 19, 0, 0) | lats[cntr]=59.926575 | lons[cntr]=30.377933
# topic=6 | (geo_cond & before_cond).sum()=11 | (geo_cond & after_cond).sum()=14 | before_mean=1.422 | after_mean=0.807
# topic=8 | (geo_cond & before_cond).sum()=11 | (geo_cond & after_cond).sum()=14 | before_mean=1.551 | after_mean=1.294
# topic=15 | (geo_cond & before_cond).sum()=11 | (geo_cond & after_cond).sum()=14 | before_mean=1.551 | after_mean=1.344
# topic=22 | (geo_cond & before_cond).sum()=11 | (geo_cond & after_cond).sum()=14 | before_mean=1.551 | after_mean=1.294
# topic=27 | (geo_cond & before_cond).sum()=11 | (geo_cond & after_cond).sum()=14 | before_mean=1.551 | after_mean=1.292
# topic=29 | (geo_cond & before_cond).sum()=11 | (geo_cond & after_cond).sum()=14 | before_mean=1.554 | after_mean=1.346
# topic=30 | (geo_cond & before_cond).sum()=11 | (geo_cond & after_cond).sum()=14 | before_mean=1.552 | after_mean=1.344
# topic=33 | (geo_cond & before_cond).sum()=11 | (geo_cond & after_cond).sum()=14 | before_mean=1.551 | after_mean=1.344
# topic=35 | (geo_cond & before_cond).sum()=11 | (geo_cond & after_cond).sum()=14 | before_mean=1.551 | after_mean=1.344
# topic=36 | (geo_cond & before_cond).sum()=11 | (geo_cond & after_cond).sum()=14 | before_mean=1.559 | after_mean=1.350
# topic=37 | (geo_cond & before_cond).sum()=11 | (geo_cond & after_cond).sum()=14 | before_mean=1.552 | after_mean=1.345
# topic=38 | (geo_cond & before_cond).sum()=11 | (geo_cond & after_cond).sum()=14 | before_mean=1.553 | after_mean=1.346
# topic=39 | (geo_cond & before_cond).sum()=11 | (geo_cond & after_cond).sum()=14 | before_mean=1.554 | after_mean=1.346
# ----------------------------------------------------------------------------------------------------
# timestamps[cntr]=datetime.datetime(2020, 11, 20, 0, 0) | lats[cntr]=59.940001 | lons[cntr]=30.469956
# topic=0 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.430 | after_mean=1.172
# topic=1 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.596 | after_mean=1.357
# topic=4 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.723 | after_mean=1.367
# topic=5 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.589 | after_mean=1.354
# topic=8 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.590 | after_mean=1.238
# topic=12 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.590 | after_mean=1.354
# topic=13 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.589 | after_mean=1.354
# topic=14 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.589 | after_mean=1.353
# topic=15 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.589 | after_mean=1.354
# topic=16 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=0.893 | after_mean=0.655
# topic=17 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.589 | after_mean=1.353
# topic=20 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.590 | after_mean=1.361
# topic=21 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.590 | after_mean=1.238
# topic=22 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.590 | after_mean=1.238
# topic=23 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.589 | after_mean=1.353
# topic=26 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.589 | after_mean=1.353
# topic=27 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.589 | after_mean=1.238
# topic=28 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.589 | after_mean=1.353
# topic=30 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.590 | after_mean=1.355
# topic=31 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.590 | after_mean=1.354
# topic=33 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.590 | after_mean=1.237
# topic=34 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.591 | after_mean=1.355
# topic=35 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.593 | after_mean=1.360
# topic=37 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.590 | after_mean=1.355
# topic=38 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.590 | after_mean=1.355
# topic=40 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.591 | after_mean=1.356
# ----------------------------------------------------------------------------------------------------
# timestamps[cntr]=datetime.datetime(2020, 11, 30, 0, 0) | lats[cntr]=59.92267 | lons[cntr]=30.448792
# topic=0 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.430 | after_mean=1.172
# topic=1 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.596 | after_mean=1.357
# topic=4 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.723 | after_mean=1.367
# topic=5 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.589 | after_mean=1.354
# topic=8 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.590 | after_mean=1.238
# topic=12 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.590 | after_mean=1.354
# topic=13 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.589 | after_mean=1.354
# topic=14 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.589 | after_mean=1.353
# topic=15 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.589 | after_mean=1.354
# topic=16 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=0.893 | after_mean=0.655
# topic=17 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.589 | after_mean=1.353
# topic=20 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.590 | after_mean=1.361
# topic=21 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.590 | after_mean=1.238
# topic=22 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.590 | after_mean=1.238
# topic=23 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.589 | after_mean=1.353
# topic=26 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.589 | after_mean=1.353
# topic=27 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.589 | after_mean=1.238
# topic=28 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.589 | after_mean=1.353
# topic=30 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.590 | after_mean=1.355
# topic=31 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.590 | after_mean=1.354
# topic=33 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.590 | after_mean=1.237
# topic=34 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.591 | after_mean=1.355
# topic=35 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.593 | after_mean=1.360
# topic=37 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.590 | after_mean=1.355
# topic=38 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.590 | after_mean=1.355
# topic=40 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=11 | before_mean=1.591 | after_mean=1.356
# ----------------------------------------------------------------------------------------------------
# timestamps[cntr]=datetime.datetime(2021, 6, 16, 0, 0) | lats[cntr]=60.006152 | lons[cntr]=30.252429
# ----------------------------------------------------------------------------------------------------
# timestamps[cntr]=datetime.datetime(2021, 3, 15, 0, 0) | lats[cntr]=60.009107 | lons[cntr]=30.24898
# all_posts_with_3 | (geo_cond & before_cond).sum()=3 | (geo_cond & after_cond).sum()=4 | before_mean=2.459 | after_mean=2.088
# ----------------------------------------------------------------------------------------------------
# timestamps[cntr]=datetime.datetime(2022, 11, 7, 0, 0) | lats[cntr]=59.833072 | lons[cntr]=30.312329
# topic=28 | (geo_cond & before_cond).sum()=16 | (geo_cond & after_cond).sum()=14 | before_mean=1.758 | after_mean=1.523
# ----------------------------------------------------------------------------------------------------
# timestamps[cntr]=datetime.datetime(2022, 7, 19, 0, 0) | lats[cntr]=59.918756 | lons[cntr]=30.469184
# topic=0 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.471 | after_mean=1.005
# topic=1 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.528 | after_mean=1.005
# topic=2 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.468 | after_mean=0.998
# topic=3 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.523 | after_mean=1.002
# topic=4 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.523 | after_mean=0.999
# topic=5 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.523 | after_mean=0.998
# topic=6 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.524 | after_mean=0.998
# topic=7 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.522 | after_mean=0.997
# topic=9 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.466 | after_mean=0.938
# topic=10 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.756 | after_mean=1.244
# topic=11 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.634 | after_mean=1.039
# topic=12 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.524 | after_mean=0.998
# topic=13 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.465 | after_mean=0.937
# topic=14 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.524 | after_mean=0.998
# topic=15 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.477 | after_mean=0.947
# topic=16 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.729 | after_mean=1.216
# topic=17 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.468 | after_mean=0.940
# topic=18 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.523 | after_mean=0.998
# topic=19 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.465 | after_mean=0.937
# topic=20 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.466 | after_mean=0.938
# topic=21 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.439 | after_mean=0.824
# topic=22 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.276 | after_mean=0.728
# topic=23 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.625 | after_mean=1.010
# topic=24 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.594 | after_mean=0.996
# topic=25 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.466 | after_mean=0.938
# topic=26 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.523 | after_mean=0.998
# topic=27 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.206 | after_mean=0.653
# topic=28 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.528 | after_mean=1.001
# topic=29 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.466 | after_mean=0.937
# topic=30 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.905 | after_mean=1.615
# topic=31 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.466 | after_mean=0.938
# topic=32 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.465 | after_mean=0.937
# topic=33 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.398 | after_mean=0.887
# topic=34 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.530 | after_mean=1.000
# topic=35 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.524 | after_mean=0.941
# topic=36 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.465 | after_mean=0.937
# topic=37 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.533 | after_mean=1.009
# topic=38 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.754 | after_mean=0.967
# topic=39 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.466 | after_mean=0.938
# topic=40 | (geo_cond & before_cond).sum()=18 | (geo_cond & after_cond).sum()=17 | before_mean=1.627 | after_mean=1.040
# ----------------------------------------------------------------------------------------------------
